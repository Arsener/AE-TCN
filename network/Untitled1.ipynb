# %%
import pandas as pd

data = pd.read_csv('../all_sepsis_patient_data/demo.csv')
data
# Out:
#       icustay_id  hr_value_0  hr_value_1  hr_value_2  hr_value_3  hr_value_4  \
# 0         200061    1.032167    0.472796    0.304984   -0.254388   -0.030639
# 1         200061    0.472796    0.304984   -0.254388   -0.030639    0.193110
# 2         200061    0.304984   -0.254388   -0.030639    0.193110    0.584670
# 3         200061   -0.254388   -0.030639    0.193110    0.584670    0.304984
# 4         200075   -0.254388   -0.590011   -0.813759   -0.520089   -0.673916
# ...          ...         ...         ...         ...         ...         ...
# 9995      204061    0.976230    0.584670    0.920293    0.920293    0.528733
# 9996      204061    0.584670    0.920293    0.920293    0.528733    0.528733
# 9997      204061    0.920293    0.920293    0.528733    0.528733    0.360921
# 9998      204061    0.920293    0.528733    0.528733    0.360921    0.360921
# 9999      204061    0.528733    0.528733    0.360921    0.360921    0.640607
#
# ...

# %%
ids = list(set(data['icustay_id']))
ids
# Out:
# [202242,
#  200708,
#  200711,
#  200208,
#  201746,
#  200724,
#  200729,
#  203296,
#  200225,
#  200231,
#  203815,
#  202799,
#  200758,
#  202308,
#  200773,
#  202309,
#  202837,
#  203362,
#  200191,
#  203888,
#  200824,
#  201850,
#  201857,
#  203911,
#  202381,
#  201358,
#  201360,
#  203410,
#  201881,
#  202907,
#  201372,
#  200349,
#  200357,
#  202919,
#  201401,
#  202425,
#  202941,
#  201920,
#  201924,
#  203460,
#  202438,
#  203979,
#  201422,
#  203471,
#  200913,
#  200916,
#  200917,
#  202965,
#  201437,
#  201962,
#  202476,
#  200944,
#  201970,
#  204020,
#  200439,
#  200441,
#  201979,
#  200450,
#  202499,
#  200453,
#  204040,
#  200463,
#  200977,
#  202515,
#  203540,
#  203543,
#  204061,
#  200994,
#  203052,
#  202030,
#  203055,
#  203571,
#  201525,
#  203584,
#  201027,
#  201046,
#  203099,
#  203105,
#  203111,
#  202089,
#  201077,
#  203129,
#  200061,
#  201598,
#  201089,
#  201092,
#  201605,
#  202629,
#  203656,
#  201098,
# ...

# %%
import random
random.shuffle(ids)
ids
# Out:
# [201089,
#  202438,
#  201098,
#  200913,
#  201979,
#  201437,
#  200191,
#  202182,
#  202499,
#  201881,
#  202684,
#  200357,
#  202308,
#  200729,
#  203111,
#  200917,
#  202965,
#  201598,
#  203471,
#  200087,
#  202139,
#  200061,
#  202629,
#  202381,
#  203105,
#  202515,
#  200625,
#  200439,
#  200916,
#  203702,
#  202799,
#  203543,
#  203674,
#  200636,
#  203656,
#  203169,
#  202425,
#  200075,
#  200231,
#  201970,
#  201027,
#  201046,
#  201659,
#  203584,
#  203186,
#  203362,
#  203979,
#  204020,
#  202242,
#  202476,
#  201746,
#  201092,
#  200944,
#  200349,
#  203410,
#  200977,
#  203571,
#  203099,
#  202941,
#  200824,
#  200708,
#  201850,
#  203460,
#  202639,
#  200758,
#  202142,
#  204061,
#  203052,
#  201605,
#  200773,
#  203815,
#  201358,
#  203540,
#  202837,
#  201962,
#  200463,
#  201401,
#  202919,
#  204040,
#  200169,
#  201372,
#  200441,
#  200143,
#  200453,
#  201612,
#  200711,
#  201215,
#  202309,
#  201125,
#  201857,
# ...

# %%
train_ids = ids[:100]
train_ids
# Out:
# [201089,
#  202438,
#  201098,
#  200913,
#  201979,
#  201437,
#  200191,
#  202182,
#  202499,
#  201881,
#  202684,
#  200357,
#  202308,
#  200729,
#  203111,
#  200917,
#  202965,
#  201598,
#  203471,
#  200087,
#  202139,
#  200061,
#  202629,
#  202381,
#  203105,
#  202515,
#  200625,
#  200439,
#  200916,
#  203702,
#  202799,
#  203543,
#  203674,
#  200636,
#  203656,
#  203169,
#  202425,
#  200075,
#  200231,
#  201970,
#  201027,
#  201046,
#  201659,
#  203584,
#  203186,
#  203362,
#  203979,
#  204020,
#  202242,
#  202476,
#  201746,
#  201092,
#  200944,
#  200349,
#  203410,
#  200977,
#  203571,
#  203099,
#  202941,
#  200824,
#  200708,
#  201850,
#  203460,
#  202639,
#  200758,
#  202142,
#  204061,
#  203052,
#  201605,
#  200773,
#  203815,
#  201358,
#  203540,
#  202837,
#  201962,
#  200463,
#  201401,
#  202919,
#  204040,
#  200169,
#  201372,
#  200441,
#  200143,
#  200453,
#  201612,
#  200711,
#  201215,
#  202309,
#  201125,
#  201857,
# ...

# %%
train_X = data[data.icustay_id.isin(train_ids)]
train_X
# Out:
#       icustay_id  hr_value_0  hr_value_1  hr_value_2  hr_value_3  hr_value_4  \
# 0         200061    1.032167    0.472796    0.304984   -0.254388   -0.030639
# 1         200061    0.472796    0.304984   -0.254388   -0.030639    0.193110
# 2         200061    0.304984   -0.254388   -0.030639    0.193110    0.584670
# 3         200061   -0.254388   -0.030639    0.193110    0.584670    0.304984
# 4         200075   -0.254388   -0.590011   -0.813759   -0.520089   -0.673916
# ...          ...         ...         ...         ...         ...         ...
# 9995      204061    0.976230    0.584670    0.920293    0.920293    0.528733
# 9996      204061    0.584670    0.920293    0.920293    0.528733    0.528733
# 9997      204061    0.920293    0.920293    0.528733    0.528733    0.360921
# 9998      204061    0.920293    0.528733    0.528733    0.360921    0.360921
# 9999      204061    0.528733    0.528733    0.360921    0.360921    0.640607
#
# ...

# %%
len(set(train_X.icustay_id))
# Out:
# 100
